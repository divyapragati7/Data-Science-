# %% [markdown]
# # BASIC STATISTICS
# Descriptive Analytics and Data Preprocessing on Sales & Discounts Dataset
# Introduction
# ●	To perform descriptive analytics, visualize data distributions, and preprocess the dataset for further analysis.
# Descriptive Analytics for Numerical Columns
# ●	Objective: To compute and analyze basic statistical measures for numerical columns in the dataset.
# ●	Steps:
# 	Load the  dataset into a data analysis tool or programming environment (e.g., Python with pandas library).
# 	Identify numerical columns in the dataset.
# 	Calculate the mean, median, mode, and standard deviation for these columns.
# 	Provide a brief interpretation of these statistics.
# Data Visualization
# ●	Objective: To visualize the distribution and relationship of numerical and categorical variables in the dataset.
# ●	Histograms:
# 	Plot histograms for each numerical column.
# 	Analyze the distribution (e.g., skewness, presence of outliers) and provide inferences.
# ●	Box Plots:
# 	Create boxplots for numerical variables to identify outliers and the interquartile range.
# 	Discuss any findings, such as extreme values or unusual distributions.
# ●	Bar Chart Analysis for Categorical Column:
# 	Identify categorical columns in the dataset.
# 	Create bar charts to visualize the frequency or count of each category.
# 	Analyze the distribution of categories and provide insights.
# Conclusion
# ●	Summarize the key findings from the descriptive analytics and data visualizations.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/sales_data_with_discounts.csv')
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date               450 non-null    object
#  1   Day                450 non-null    object
#  2   SKU                450 non-null    object
#  3   City               450 non-null    object
#  4   Volume             450 non-null    int64
#  5   BU                 450 non-null    object
#  6   Brand              450 non-null    object
#  7   Model              450 non-null    object
#  8   Avg Price          450 non-null    int64
#  9   Total Sales Value  450 non-null    int64
#  10  Discount Rate (%)  450 non-null    float64
#  11  Discount Amount    450 non-null    float64
#  12  Net Sales Value    450 non-null    float64
# dtypes: float64(3), int64(3), object(7)
# memory usage: 45.8+ KB

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102961
# 2      16100             112700           9.456886     10657.910157
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0    160346.501180
# 1     89323.897039
# 2    102042.089843
# 3    112235.925298
# 4     19927.053770

# %%
df.tail()
# Out:
#            Date       Day  SKU City  Volume         BU  Brand      Model  \
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera  M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva  W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva   W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera  M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera    M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 445       1300               2600          15.475687       402.367873
# 446       2600              15600          17.057027      2660.896242
# 447       1600               3200          18.965550       606.897606
# 448       1900               5700          16.793014       957.201826
# 449       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# 445      2197.632127
# 446     12939.103758
# 447      2593.102394
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'Volume', 'BU', 'Brand', 'Model',
#        'Avg Price', 'Total Sales Value', 'Discount Rate (%)',
#        'Discount Amount', 'Net Sales Value'],
#       dtype='object')

# %%
numerical_cols = df.select_dtypes(include='number')
numerical_cols
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0        15      12100             181500          11.654820     21153.498820
# 1        10      10100             101000          11.560498     11676.102961
# 2         7      16100             112700           9.456886     10657.910157
# 3         6      20100             120600           6.935385      8364.074702
# 4         3       8100              24300          17.995663      4372.946230
# ..      ...        ...                ...                ...              ...
# 445       2       1300               2600          15.475687       402.367873
# 446       6       2600              15600          17.057027      2660.896242
# 447       2       1600               3200          18.965550       606.897606
# 448       3       1900               5700          16.793014       957.201826
# 449       1       3100               3100          15.333300       475.332295
#
#      Net Sales Value
# ...

# %%
numerical_cols.mean() # this gives average values of each and every column
# Out:
# Volume                   5.066667
# Avg Price            10453.433333
# Total Sales Value    33812.835556
# Discount Rate (%)       15.155242
# Discount Amount       3346.499424
# Net Sales Value      30466.336131
# dtype: float64

# %%
numerical_cols.median() #the median value here provided here are the centre most values in the columns
# Out:
# Volume                  4.000000
# Avg Price            1450.000000
# Total Sales Value    5700.000000
# Discount Rate (%)      16.577766
# Discount Amount       988.933733
# Net Sales Value      4677.788059
# dtype: float64

# %%
numerical_cols.mode() #mode is a frequent values however i believe the results here doesnt make sense for repeatition values
# Out:
#      Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0       3.0      400.0            24300.0           5.007822        69.177942
# 1       NaN      450.0                NaN           5.055218        73.025199
# 2       NaN      500.0                NaN           5.059801        93.649161
# 3       NaN     1300.0                NaN           5.072124        94.682735
# 4       NaN     8100.0                NaN           5.084108       102.705757
# ..      ...        ...                ...                ...              ...
# 445     NaN        NaN                NaN          19.940610     17900.983733
# 446     NaN        NaN                NaN          19.965340     21153.498820
# 447     NaN        NaN                NaN          19.976879     21496.675367
# 448     NaN        NaN                NaN          19.982257     25328.224204
# 449     NaN        NaN                NaN          19.992407     25738.022194
#
#      Net Sales Value
# ...

# %%
numerical_cols.std() # the values here shows the variation from mean value
# Out:
# Volume                   4.231602
# Avg Price            18079.904840
# Total Sales Value    50535.074173
# Discount Rate (%)        4.220602
# Discount Amount       4509.902963
# Net Sales Value      46358.656624
# dtype: float64

# %%
plt.hist(df['Volume'],facecolor="orange",edgecolor="black",bins=6)
plt.title=("Volume Distribution")
plt.xlabel=("Volume")
plt.ylabel=("Frequency")
#there are outliers and is left skewed

# %%
plt.hist(df['Avg Price'],facecolor="orange",edgecolor="black",bins=6)
plt.title=("Avg Price Distribution")
plt.xlabel=("Avg Price")
plt.ylabel=("Frequency")
#there are missing values in these AVg price

# %%
plt.hist(df['Total Sales Value'],facecolor="yellow",edgecolor="black")
#the data here is left skewed and also has outliers
# Out:
# (array([305.,  24.,  15.,  18.,  12.,  27.,  15.,  15.,  11.,   8.]),
#  array([   400.,  20000.,  39600.,  59200.,  78800.,  98400., 118000.,
#         137600., 157200., 176800., 196400.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Discount Rate (%)'],facecolor="red",edgecolor="black")
#the data here is right skewed and also has outliers but the data is not very low
# Out:
# (array([ 27.,  24.,  29.,  14.,  14.,   6.,  38.,  96., 115.,  87.]),
#  array([ 5.00782219,  6.50628067,  8.00473916,  9.50319765, 11.00165613,
#         12.50011462, 13.9985731 , 15.49703159, 16.99549007, 18.49394856,
#         19.99240704]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Discount Amount'],facecolor="blue",edgecolor="black")
#the data here is left skewed and has outliers
# Out:
# (array([299.,  37.,  42.,  29.,  22.,   8.,   9.,   0.,   2.,   2.]),
#  array([   69.17794229,  2636.06236744,  5202.94679258,  7769.83121773,
#         10336.71564288, 12903.60006802, 15470.48449317, 18037.36891832,
#         20604.25334346, 23171.13776861, 25738.02219376]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Net Sales Value'],facecolor="green",edgecolor="black")
#the data here is left skewed and has outliers
# Out:
# (array([306.,  26.,  17.,  14.,   8.,  30.,  16.,  15.,  12.,   6.]),
#  array([   326.97480055,  18245.0252254 ,  36163.07565025,  54081.1260751 ,
#          71999.17649994,  89917.22692479, 107835.27734964, 125753.32777448,
#         143671.37819933, 161589.42862418, 179507.47904902]),
#  <BarContainer object of 10 artists>)

# %%
df.plot(kind ='box') # there are outliers in all the columns. to make it normal distribution i need to remove the outlayers
# Out:
# <Axes: >

# %%
df['Volume'].plot(kind = 'box') # here Volume has Outliers close to the UW
# Out:
# <Axes: >

# %%
df['Volume'].describe()
# Out:
# count    450.000000
# mean       5.066667
# std        4.231602
# min        1.000000
# 25%        3.000000
# 50%        4.000000
# 75%        6.000000
# max       31.000000
# Name: Volume, dtype: float64

# %%
Q1= np.percentile(df['Volume'],25)
print('Q1:',Q1)
Q3 = np.percentile(df['Volume'],75)
print('Q2:',Q3)
# Out:
# Q1: 3.0
# Q2: 6.0

# %%
IQR= Q3-Q1
IQR
# Out:
# np.float64(3.0)

# %%
uw = Q3+(1.5*IQR)
uw
# Out:
# np.float64(10.5)

# %%
lw = Q1-(1.5*IQR)
lw
# Out:
# np.float64(-1.5)

# %%
df['Avg Price'].plot(kind = 'box', vert = False) # there are extreme outliers in this price
# Out:
# <Axes: >

# %%
df['Avg Price'].describe()
# Out:
# count      450.000000
# mean     10207.871111
# std      18147.908783
# min         10.500000
# 25%        450.000000
# 50%       1300.000000
# 75%       8100.000000
# max      60100.000000
# Name: Avg Price, dtype: float64

# %%
Q1=np.percentile(df['Avg Price'],25)
print('Q1:',Q1)
Q3 = np.percentile(df['Avg Price'],75)
print('Q3:',Q3)
IQR=Q3-Q1
IQR
# Out:
# Q1: 450.0
# Q3: 8100.0
# np.float64(7650.0)

# %%
uw = Q3+(1.5*IQR)
uw
# Out:
# np.float64(19575.0)

# %%
lw = Q1*-(1.5*IQR)
lw
# Out:
# np.float64(-5163750.0)

# %%
df['Total Sales Value'].plot(kind = 'box', vert = False)
# Out:
# <Axes: >

# %%
df['Total Sales Value'].describe()
# Out:
# count       450.000000
# mean      30547.628889
# std       48189.907228
# min          10.500000
# 25%        1695.000000
# 50%        4500.000000
# 75%       39450.000000
# max      196400.000000
# Name: Total Sales Value, dtype: float64

# %%
Q1=np.percentile(df['Total Sales Value'],25)
print('Q1:',Q1)
Q3 = np.percentile(df['Total Sales Value'],75)
print('Q3:',Q3)
IQR=Q3-Q1
IQR
# Out:
# Q1: 1695.0
# Q3: 39450.0
# np.float64(37755.0)

# %%
uw = Q3+(1.5*IQR)
uw
# Out:
# np.float64(96082.5)

# %%
lw = Q1-(1.5*IQR)
lw
# there are high end outliwers present due the the values exceeding above the Upper wiskers. IQR shows high variability
# Out:
# np.float64(-54937.5)

# %%
df['Discount Rate (%)'].plot(kind = 'box') # there are no outliers in Discount rate column and the data is evenly distributed
# Out:
# <Axes: >

# %%
df['Discount Rate (%)'].describe()
# Out:
# count    450.000000
# mean      14.538862
# std        4.330624
# min        5.007822
# 25%       10.500000
# 50%       16.134217
# 75%       17.911868
# max       19.992407
# Name: Discount Rate (%), dtype: float64

# %%
Q1 = df['Discount Rate (%)']. quantile(0.25)
print('Q1:',Q1)
Q3 = df['Discount Rate (%)']. quantile(0.75)
print('Q3:',Q3)
IQR=Q3-Q1
IQR
# Out:
# Q1: 10.5
# Q3: 17.911868149526363
# np.float64(7.411868149526363)

# %%
df['Discount Amount'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
df['Discount Amount'].describe() # here upper wisker is around 10k but the maximum values are above 17900. hence there are extreme outliers
# Out:
# count      450.000000
# mean      2902.836919
# std       3947.848850
# min         10.500000
# 25%        292.742987
# 50%        791.870637
# 75%       4596.510208
# max      17900.983733
# Name: Discount Amount, dtype: float64

# %%
Q3 = df['Discount Amount'].quantile(0.75)
print('Q3:',Q3)
Q1 = df['Discount Amount'].quantile(0.25)
print('Q1:',Q1)

IQR = Q3-Q1
IQR
# Out:
# Q3: 4596.510208331974
# Q1: 292.74298676928123
# np.float64(4303.7672215626935)

# %%
uw = Q3+(1.5*IQR)
print('uw:',uw)
lW = Q1-(1.5*IQR)
print('lw:',lw)
# Out:
# uw: 11052.161040676016
# lw: -54937.5

# %%
df['Net Sales Value'].plot(kind='box')
# Out:
# <Axes: >

# %%
df['Net Sales Value'].describe() # net sales value also has huge outliers since max values is 179507 which is beyond the uw which is at 75000
# Out:
# count       450.000000
# mean      27645.818636
# std       44476.698018
# min          10.500000
# 25%        1421.756898
# 50%        3753.655508
# 75%       32442.516784
# max      179507.479049
# Name: Net Sales Value, dtype: float64

# %%
Q3 = np.percentile(df['Net Sales Value'],25)
print('Q3:',Q3)
Q1 = np.percentile(df['Net Sales Value'],75)
print('Q1:',Q1)
IQR= Q3-Q1
IQR
# Out:
# Q3: 1421.7568976141554
# Q1: 32442.51678447604
# np.float64(-31020.759886861884)

# %%
uw=Q3+(1.5*IQR)
print('uw:',uw)
lw=Q1-(1.5*IQR)
print('lw:',lw)
# Out:
# uw: -45109.38293267867
# lw: 78973.65661476887

# %%
categorical_cols = df.select_dtypes(include='object')
categorical_cols
# categorical_cols = df.select_dtypes(include=['object']).columns
# Out:
#            Date       Day   SKU  City         BU  Brand       Model
# 0          10.5      10.5  10.5  10.5       10.5   10.5        10.5
# 1    01-04-2021  Thursday   M02     C    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday   M03     C    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday   M04     C    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday   M05     C    Mobiles   YouM      YM-98
# ..          ...       ...   ...   ...        ...    ...         ...
# 445  15-04-2021  Thursday   L06     C  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday   L07     C  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday   L08     C  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday   L09     C  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday   L10     C  Lifestyle  Jeera     M-Shoes
#
# [450 rows x 7 columns]

# %%
df[['Brand','BU' ,'Model','City']].value_counts()
# Out:
# Brand    BU         Model           City
# 10.5     10.5       10.5            10.5    44
# Babaji   FMCG       Babaji Cream    C       15
# Gear     FMCG       Gear BB Cream   C       15
#                     Gear Oil        C       15
#                     Gear Cream      C       15
# Jeera    Lifestyle  M-Casuals       C       15
# Gear     FMCG       Gear Shampoo    C       15
# Jeera    Lifestyle  M-Shoes         C       15
# Orange   Mobiles    O-10            C       15
# Jeera    Lifestyle  M-Jeans         C       15
#                     M-Formals       C       15
# Sumsang  Mobiles    S-20            C       15
# RealU    Mobiles    RU-9 Plus       C       15
#                     RU-9            C       15
# Orange   Mobiles    O-11            C       15
# YouM     Mobiles    YM-99           C       15
#                     YM-98           C       15
# Viva     Lifestyle  W-Lounge        C       15
#                     W-Western       C       15
# ...

# %% [markdown]
# I dint understand further as bar plot is usually plot between categorical and numerical column. I will need help in this please.
